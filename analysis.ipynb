# %%
from feedforward.plot_decision import plot_decision_boundary

# %%
from feedforward.example3 import NeuralNet, X, y

# %%
net = NeuralNet(5)
net.train(X, y)
# Out:
# Output
# [[ 0.00954329]
#  [ 0.99349692]
#  [ 0.9880828 ]
#  [ 0.01074717]]

# %%
net.predict([[1, 1]])
# Out:
# array([[ 0.01074651]])

# %%
plot_decision_boundary(net.predict, X, y)
